# %% [markdown]
# # AI-Powered Lead Scoring Agent
#
# ## Overview
# This agent automatically scores B2B leads using a custom scoring framework built on domain expertise in Marketing Technology and Revenue Ops.
#
# ## Scoring Framework
# - **Job Title** (25 points) — seniority determines budget authority
# - **Company Size** (20 points) — larger companies have more complex needs and bigger budgets
# - **Intent Signal** (25 points) — 6sense-style behavioral intent matching
# - **Engagement** (30 points) — website visits, email opens, form submissions
#
# ## Tech Stack
# - Python
# - Anthropic Claude API (claude-haiku)
# - Jupyter Notebook
#
# ## Author
# Karthik — Marketing Automation Manager | MarTech & Revenue Operations

# %% [markdown]
# ## Setup Instructions
# To run this notebook you need an Anthropic API key.
#
# 1. Create a file called `.env` in the same folder as this notebook
# 2. Add this line to the file: `ANTHROPIC_API_KEY=your-key-here`
# 3. Replace `your-key-here` with your actual Anthropic API key
# 4. Never upload your `.env` file to GitHub

# %%
# Run this once to create your .env file
# Replace 'your-key-here' with your actual Anthropic API key

#with open('.env', 'w') as f:
#   f.write('ANTHROPIC_API_KEY=your-key-here')

# %%
# !pip install anthropic
# !pip install python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\users\karthik pc\anaconda3\lib\site-packages (0.102.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\karthik pc\anaconda3\lib\site-packages (from anthropic) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\karthik pc\anaconda3\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\karthik pc\anaconda3\lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\karthik pc\anaconda3\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\karthik pc\anaconda3\lib\site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\karthik pc\anaconda3\lib\site-packages (from anthropic) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\karthik pc\anaconda3\lib\site-packages (from anthropic) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\karthik pc\anaconda3\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\karthik pc\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in c:\users\karthik pc\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\karthik pc\anaconda3\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\karthik pc\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\karthik pc\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\karthik pc\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\karthik pc\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: python-dotenv in c:\users\karthik pc\anaconda3\lib\site-packages (1.1.0)

# %%
from dotenv import load_dotenv
import os
import anthropic

load_dotenv()
client = anthropic.Anthropic()

# %%
lead = {
    "name": "Rahul Sharma",
    "title": "VP of Marketing",
    "company": "TechCorp India",
    "employees": 500,
    "intent_topic": "Marketing Automation",
    "email_opened": True,
    "form_submitted": False,
    "website_visits": 8
}

# %%
scoring_criteria = """
You are a B2B SaaS lead scoring expert. Score the lead from 0-100 using these exact criteria:

JOB TITLE (max 25 points):
- C-Suite / VP level = 25 points
- Director level = 20 points
- Manager level = 15 points
- Individual Contributor = 5 points

COMPANY SIZE (max 20 points):
- 500+ employees = 20 points
- 200-499 employees = 15 points
- 50-199 employees = 10 points
- Under 50 employees = 5 points

INTENT SIGNAL (max 25 points):
- Topic directly matches our product = 25 points
- Topic loosely related = 15 points
- No intent signal = 0 points

ENGAGEMENT (max 30 points):
- Website visits 10+ = 20 points
- Website visits 5-9 = 15 points
- Website visits 1-4 = 5 points
- Email opened = 5 points
- Form submitted = 5 points

Return your response in this format:
SCORE: [number]/100
BREAKDOWN: [explain each category]
RECOMMENDATION: [Hot/Warm/Cold]
NEXT ACTION: [one specific action]
"""

# %%
message = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=1024,
messages=[
    {
        "role":"user",
        "content":f"You are a MarTech Lead scoring expert. Use this {scoring_criteria} and score this lead:\n{lead}"
    }
]
)
print(message.content[0].text)
# Out:
# SCORE: 85/100
#
# BREAKDOWN:
# - **JOB TITLE (25/25)**: VP of Marketing = VP level = 25 points ✓
# - **COMPANY SIZE (20/20)**: 500+ employees = 20 points ✓
# - **INTENT SIGNAL (25/25)**: Marketing Automation directly matches typical MarTech product offerings = 25 points ✓
# - **ENGAGEMENT (15/30)**: Website visits 5-9 (8 visits) = 15 points; Email opened = 5 points; Form NOT submitted = 0 points. Total = 15 points
#
# RECOMMENDATION: **HOT**
#
# NEXT ACTION: Schedule a personalized demo call within 24 hours, referencing their 8 website visits and specific interest in Marketing Automation capabilities.

# %%
leads = [
    {
        "name": "Rahul Sharma",
        "title": "VP of Marketing",
        "company": "TechCorp India",
        "employees": 500,
        "intent_topic": "Marketing Automation",
        "email_opened": True,
        "website_visits": 8,
        "form_submitted": False
    },
    {
        "name": "Priya Patel",
        "title": "Marketing Manager",
        "company": "StartupXYZ",
        "employees": 45,
        "intent_topic": "Email Marketing",
        "email_opened": True,
        "website_visits": 3,
        "form_submitted": False
    },
    {
        "name": "James Wilson",
        "title": "CMO",
        "company": "Enterprise Corp",
        "employees": 2000,
        "intent_topic": "Marketing Automation",
        "email_opened": True,
        "website_visits": 12,
        "form_submitted": True
    },
    {
        "name": "Anita Rao",
        "title": "Director of Demand Gen",
        "company": "MidMarket Inc",
        "employees": 300,
        "intent_topic": "Lead Routing",
        "email_opened": False,
        "website_visits": 6,
        "form_submitted": False
    },
    {
        "name": "David Lee",
        "title": "Marketing Coordinator",
        "company": "SmallBiz Co",
        "employees": 20,
        "intent_topic": "Social Media",
        "email_opened": False,
        "website_visits": 1,
        "form_submitted": False
    }
]

# %%
for lead in leads:
    print(f"\n{'='*50}")
    print(f"Scoring lead: {lead['name']} - {lead['title']}")
    print(f"{'='*50}")
    
    message = client.messages.create(
        model="claude-haiku-4-5-20251001",
        max_tokens=1024,
        messages=[
            {
            "role":"user",
            "content":f"You are a MarTech Lead scoring expert. Use this {scoring_criteria} and score this lead:\n{lead}"
            }
        ]
    )
    print(message.content[0].text)
# Out:
# ==================================================
# Scoring lead: Rahul Sharma - VP of Marketing
# ==================================================
# SCORE: 85/100
#
# BREAKDOWN:
# - **JOB TITLE (25/25):** VP of Marketing = VP level = 25 points
# - **COMPANY SIZE (20/20):** 500+ employees = 20 points
# - **INTENT SIGNAL (25/25):** Marketing Automation directly matches B2B SaaS marketing product = 25 points
# - **ENGAGEMENT (15/30):** Website visits 5-9 (8 visits) = 15 points + Email opened = 5 points. Form not submitted = 0 points. Total = 15 points
#
# RECOMMENDATION: **HOT**
#
# NEXT ACTION: Schedule a demo call within 24 hours. Rahul is a high-authority decision-maker at an enterprise company showing strong buying intent and active engagement. The 8 website visits + email open demonstrate genuine interest—capitalize on this momentum before engagement cools.
#
# ==================================================
# Scoring lead: Priya Patel - Marketing Manager
# ==================================================
# SCORE: 40/100
#
# BREAKDOWN:
# - **Job Title (15 points):** Marketing Manager = Manager level
# - **Company Size (5 points):** 45 employees = Under 50 employees
# - **Intent Signal (25 points):** Email Marketing directly matches product offering
# - **Engagement (10 points):** 3 website visits (5 points) + Email opened (5 points)
#
# RECOMMENDATION: Warm
#
# NEXT ACTION: Send targeted email with case study showing how similar marketing managers at small companies improved email campaign performance, and include a low-friction demo offer or product walkthrough link.
#
# ==================================================
# Scoring lead: James Wilson - CMO
# ==================================================
# SCORE: 90/100
#
# BREAKDOWN:
# - **JOB TITLE (25/25)**: CMO is C-Suite level = 25 points
# - **COMPANY SIZE (20/20)**: 2,000 employees exceeds 500+ threshold = 20 points
# - **INTENT SIGNAL (25/25)**: Marketing Automation directly matches core product offering = 25 points
# - **ENGAGEMENT (20/30)**:
#   - Website visits 12 (10+) = 20 points
#   - Email opened = 5 points (already counted in website visits tier)
#   - Form submitted = 5 points (already counted in website visits tier)
#   - *Note: Using highest engagement category = 20 points total*
#
# RECOMMENDATION: **HOT**
#
# NEXT ACTION: Schedule a discovery call with James within 24 hours. Prepare talking points around marketing automation ROI and enterprise-scale implementation, as he has demonstrated strong buying signals across all metrics.
#
# ==================================================
# Scoring lead: Anita Rao - Director of Demand Gen
# ==================================================
# SCORE: 65/100
#
# BREAKDOWN:
# - **Job Title (20 points)**: Director level = 20 points ✓
# - **Company Size (15 points)**: 300 employees falls in 200-499 range = 15 points ✓
# - **Intent Signal (25 points)**: Lead Routing is directly relevant to demand gen/MarTech product = 25 points ✓
# - **Engagement (5 points)**: 6 website visits (5-9 range) = 15 points, but no email opens or form submission = 5 points total ✓
#
# RECOMMENDATION: **WARM**
#
# This is a qualified prospect with strong fit indicators (right seniority level, suitable company size, direct product relevance), but engagement signals are weak. The lead has shown moderate interest through browsing but hasn't converted to higher-intent actions.
#
# NEXT ACTION: **Send a personalized email addressing Lead Routing challenges specific to demand generation**, referencing their 6 website visits as social proof of interest. Include a clear CTA to either schedule a 15-min demo or download a relevant resource (e.g., "Lead Routing Best Practices for Demand Gen Teams").
#
# ==================================================
# Scoring lead: David Lee - Marketing Coordinator
# ==================================================
# SCORE: 20/100
#
# BREAKDOWN:
# - **Job Title (5 points):** Marketing Coordinator = Individual Contributor level
# - **Company Size (5 points):** 20 employees = Under 50 employees
# - **Intent Signal (0 points):** Social Media is not directly related to typical B2B SaaS products (assumes marketing/sales automation focus)
# - **Engagement (10 points):** 1 website visit = 5 points; No email opens or form submissions
#
# RECOMMENDATION: **Cold**
#
# NEXT ACTION: Add to nurture campaign with educational content about how your solution addresses social media marketing challenges (if applicable to your product). Consider re-engaging only if additional intent signals emerge or if they submit a form/show repeated engagement.
#
# ---
#
# **Note:** This lead has low priority. Focus resources on warmer leads with higher job titles, larger companies, and stronger engagement signals.
